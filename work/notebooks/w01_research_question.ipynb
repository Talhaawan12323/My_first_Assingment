# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
I am choosing Lane 4 CTR Engagement Opportunity Scoring. I selected this because a page that already ranks well but has a low CTR is a missed opportunity. Fixing a title or meta description is much cheaper and faster than writing a completely new article.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
Which pages are ranking well on Google (Page 1 or 2) but under-capturing clicks, and thus need a metadata review?
Ans)The content team will rewrite the title tags and meta descriptions for these specific pages to make them more clickable.
Cost: If the model recommends the wrong page, a writer wastes time changing a title that was already performing well, which could accidentally lower the existing traffic.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")
page_one = df[(df['avg_position'] > 0) & (df['avg_position'] <= 10) & (df['impressions_90d'] >= 500)]
low_ctr = page_one[page_one['ctr'] < 0.01]

print("Total visible pages on Page 1:", len(page_one))
print("Pages on Page 1 but with low CTR:", len(low_ctr))
print("Percentage of missed opportunities:", (len(low_ctr) / len(page_one)) * 100)
# Out:
# Total visible pages on Page 1: 7564
# Pages on Page 1 but with low CTR: 550
# Percentage of missed opportunities: 7.271285034373347

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
I can Claim : Which pages have a statistically lower CTR compared to other pages in the same ranking tier.
I cannot claim: That rewriting the title will 100% guarantee an increase in clicks (since we are observing data, not running an A/B test), nor can I claim I know exactly how Google's algorithm works.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [checked ] Every section above is filled — markdown thinking AND the code that backs it
# - [checked] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [checked ] No client names, URLs, or private queries anywhere
# - [checked ] My claims use careful words: observed, measured, directional, decision-support
# - [checked] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
